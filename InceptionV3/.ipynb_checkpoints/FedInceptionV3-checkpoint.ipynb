# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report, precision_score, recall_score, f1_score
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam

# Define the CNN model
def create_inceptionv3_model():
    base_model = InceptionV3(weights='imagenet', include_top=False, input_shape=(128, 128, 3))
    x = base_model.output
    x = GlobalAveragePooling2D()(x)
    x = Dense(256, activation='relu')(x)  # Increased units in the dense layer
    predictions = Dense(1, activation='sigmoid')(x)
    model = Model(inputs=base_model.input, outputs=predictions)
    
    for layer in base_model.layers:
        layer.trainable = False
    
    model.compile(optimizer=Adam(learning_rate=0.0001), loss='binary_crossentropy', metrics=['accuracy'])  # Changed optimizer to Adam

    return model

# Define a function to load data from a local dataset
def load_data(client_folder):
    data = []
    labels = []
    for category in ['cataract', 'normal']:
        category_folder = os.path.join(client_folder, category)
        label = 1 if category == 'cataract' else 0
        for image_file in os.listdir(category_folder):
            image_path = os.path.join(category_folder, image_file)
            img = tf.io.read_file(image_path)
            img = tf.image.decode_jpeg(img, channels=3)
            img = tf.image.resize(img, [128, 128])
            img = img / 255.0
            data.append(img.numpy())
            labels.append(label)
    return np.array(data), np.array(labels)

# Define a custom federated averaging algorithm
def custom_federated_averaging(global_model, local_model):
    for global_layer, local_layer in zip(global_model.layers, local_model.layers):
        weights = [0.5 * (global_w + local_w) for global_w, local_w in zip(global_layer.get_weights(), local_layer.get_weights())]
        global_layer.set_weights(weights)
    return global_model

# Define a function to split data into training and testing sets
def split_train_test_data(data, labels, test_ratio=0.2):
    num_samples = len(data)
    num_test_samples = int(test_ratio * num_samples)

    # Randomly shuffle data and labels
    indices = np.random.permutation(num_samples)
    data = data[indices]
    labels = labels[indices]

    # Split into train and test sets
    test_data = data[:num_test_samples]
    test_labels = labels[:num_test_samples]
    train_data = data[num_test_samples:]
    train_labels = labels[num_test_samples:]

    return train_data, train_labels, test_data, test_labels

# Define a function to perform local training
def train_local_model(local_model, data, labels):
    local_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
    history = local_model.fit(data, labels, epochs=10, batch_size=32)
    return local_model, history

# Main federated learning process
if __name__ == '__main__':
    # Define the client folders
    client_folders = ['ds1', 'ds2', 'ds3', 'ds4', 'ds5']

    # Set the current directory
    current_dir = os.getcwd()

    # Create local models
    local_models = [create_inceptionv3_model() for _ in client_folders]
    
    # Initialize lists to store metrics
    train_metrics = []
    test_metrics = []
    
    # Train local models and evaluate on both train and test data
    for i, client_folder in enumerate(client_folders):
        client_folder_path = os.path.join(current_dir, client_folder)
        data, labels = load_data(client_folder_path)

        # Split data into train and test sets
        train_data, train_labels, test_data, test_labels = split_train_test_data(data, labels)

        local_models[i], history = train_local_model(local_models[i], train_data, train_labels)

        # Plot accuracy graph for each local model
        plt.plot(history.history['accuracy'], label=f'Local Model {i+1}')

        # Evaluate on train data
        train_loss, train_accuracy = local_models[i].evaluate(train_data, train_labels, verbose=0)
        train_predictions = (local_models[i].predict(train_data) > 0.5).astype('int32')

        # Calculate precision, recall, F1-score for train data
        train_precision = precision_score(train_labels, train_predictions)
        train_recall = recall_score(train_labels, train_predictions)
        train_f1_score = f1_score(train_labels, train_predictions)

        train_metrics.append((train_accuracy, train_precision, train_recall, train_f1_score))

        # Evaluate on test data
        test_loss, test_accuracy = local_models[i].evaluate(test_data, test_labels, verbose=0)
        test_predictions = (local_models[i].predict(test_data) > 0.5).astype('int32')

        # Calculate precision, recall, F1-score for test data
        test_precision = precision_score(test_labels, test_predictions)
        test_recall = recall_score(test_labels, test_predictions)
        test_f1_score = f1_score(test_labels, test_predictions)

        test_metrics.append((test_accuracy, test_precision, test_recall, test_f1_score))

        test_report = classification_report(test_labels, test_predictions, target_names=['Normal', 'Cataract'], zero_division=1)
        train_report = classification_report(train_labels, train_predictions, target_names=['Normal', 'Cataract'], zero_division=1)

        print(f'Local Model {i+1} Train Accuracy: {train_accuracy * 100:.2f}%')
        print(f'Local Model {i+1} Train Precision: {train_precision:.2f}')
        print(f'Local Model {i+1} Train Recall: {train_recall:.2f}')
        print(f'Local Model {i+1} Train F1-score: {train_f1_score:.2f}\n')
        print(f'Local Model {i+1} Test Accuracy: {test_accuracy * 100:.2f}%')
        print(f'Local Model {i+1} Test Precision: {test_precision:.2f}')
        print(f'Local Model {i+1} Test Recall: {test_recall:.2f}')
        print(f'Local Model {i+1} Test F1-score: {test_f1_score:.2f}\n')
        print(f'Local Model {i+1} Classification Report (Train Data):')
        print(train_report)
        print(f'Local Model {i+1} Classification Report (Test Data):')
        print(test_report)

    # Initialize global model
    global_model = create_inceptionv3_model()

    # Update global model with local models
    for local_model in local_models:
        global_model = custom_federated_averaging(global_model, local_model)

    # Save models
    global_model.save('global_model.h5')

    for i, local_model in enumerate(local_models):
        local_model.save(f'local_model_ds{i+1}.h5')

    # Load global model and compile it
    global_model = tf.keras.models.load_model('global_model.h5')
    global_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

    # Evaluate global model on the entire dataset
    global_data, global_labels = [], []
    for client_folder in client_folders:
        client_folder_path = os.path.join(current_dir, client_folder)
        data, labels = load_data(client_folder_path)
        global_data.extend(data)
        global_labels.extend(labels)

    global_data, global_labels = np.array(global_data), np.array(global_labels)
    global_accuracy = global_model.evaluate(global_data, global_labels)[1]
    print(f'Global Model Accuracy: {global_accuracy * 100:.2f}%')

    # Calculate and display confusion matrix
    predictions = (global_model.predict(global_data) > 0.5).astype('int32')
    cm = confusion_matrix(global_labels, predictions)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=['Normal', 'Cataract'])
    disp.plot(cmap=plt.cm.Blues)
    plt.show()

    # Additional Evaluation Metrics
    predictions = (global_model.predict(global_data) > 0.5).astype('int32')
    report = classification_report(global_labels, predictions, target_names=['Normal', 'Cataract'], zero_division=1)
    print("Classification Report:")
    print(report)

    # Evaluate on train data
    train_loss, train_accuracy = global_model.evaluate(global_data, global_labels, verbose=0)
    train_predictions = (global_model.predict(global_data) > 0.5).astype('int32')

    # Calculate precision, recall, F1-score for train data
    train_precision = precision_score(global_labels, train_predictions)
    train_recall = recall_score(global_labels, train_predictions)
    train_f1_score = f1_score(global_labels, train_predictions)

    print(f'Global Model Train Accuracy: {train_accuracy * 100:.2f}%')
    print(f'Global Model Train Precision: {train_precision:.2f}')
    print(f'Global Model Train Recall: {train_recall:.2f}')
    print(f'Global Model Train F1-score: {train_f1_score:.2f}\n')

    # Evaluate on test data
    test_loss, test_accuracy = global_model.evaluate(global_data, global_labels, verbose=0)
    test_predictions = (global_model.predict(global_data) > 0.5).astype('int32')

    # Calculate precision, recall, F1-score for test data
    test_precision = precision_score(global_labels, test_predictions)
    test_recall = recall_score(global_labels, test_predictions)
    test_f1_score = f1_score(global_labels, test_predictions)

    print(f'Global Model Test Accuracy: {test_accuracy * 100:.2f}%')
    print(f'Global Model Test Precision: {test_precision:.2f}')
    print(f'Global Model Test Recall: {test_recall:.2f}')
    print(f'Global Model Test F1-score: {test_f1_score:.2f}\n')
# Out:
# Epoch 1/10
# 10/10 [==============================] - 17s 814ms/step - loss: 1.0435 - accuracy: 0.8103
# Epoch 2/10
# 10/10 [==============================] - 6s 577ms/step - loss: 0.3188 - accuracy: 0.9100
# Epoch 3/10
# 10/10 [==============================] - 7s 715ms/step - loss: 0.2020 - accuracy: 0.9164
# Epoch 4/10
# 10/10 [==============================] - 7s 677ms/step - loss: 0.1589 - accuracy: 0.9453
# Epoch 5/10
# 10/10 [==============================] - 5s 515ms/step - loss: 0.1271 - accuracy: 0.9582
# Epoch 6/10
# 10/10 [==============================] - 6s 630ms/step - loss: 0.0568 - accuracy: 0.9839
# Epoch 7/10
# 10/10 [==============================] - 5s 476ms/step - loss: 0.0449 - accuracy: 0.9904
# Epoch 8/10
# 10/10 [==============================] - 5s 517ms/step - loss: 0.0360 - accuracy: 0.9904
# Epoch 9/10
# 10/10 [==============================] - 7s 666ms/step - loss: 0.0286 - accuracy: 0.9968
# Epoch 10/10
# 10/10 [==============================] - 5s 526ms/step - loss: 0.0292 - accuracy: 0.9936
# 10/10 [==============================] - 7s 466ms/step
# 3/3 [==============================] - 1s 365ms/step
# Local Model 1 Train Accuracy: 99.68%
# Local Model 1 Train Precision: 0.99
# Local Model 1 Train Recall: 1.00
# Local Model 1 Train F1-score: 1.00
#
# Local Model 1 Test Accuracy: 93.51%
# Local Model 1 Test Precision: 0.97
# Local Model 1 Test Recall: 0.90
# Local Model 1 Test F1-score: 0.93
#
# Local Model 1 Classification Report (Train Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00       186
#     Cataract       0.99      1.00      1.00       125
#
#     accuracy                           1.00       311
#    macro avg       1.00      1.00      1.00       311
# weighted avg       1.00      1.00      1.00       311
#
# Local Model 1 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.97      0.94        38
#     Cataract       0.97      0.90      0.93        39
#
#     accuracy                           0.94        77
#    macro avg       0.94      0.94      0.94        77
# weighted avg       0.94      0.94      0.93        77
#
# Epoch 1/10
# 12/12 [==============================] - 16s 479ms/step - loss: 0.7654 - accuracy: 0.8135
# Epoch 2/10
# 12/12 [==============================] - 7s 603ms/step - loss: 0.1740 - accuracy: 0.9595
# Epoch 3/10
# 12/12 [==============================] - 6s 477ms/step - loss: 0.1155 - accuracy: 0.9703
# Epoch 4/10
# 12/12 [==============================] - 7s 568ms/step - loss: 0.0667 - accuracy: 0.9703
# Epoch 5/10
# 12/12 [==============================] - 7s 583ms/step - loss: 0.0425 - accuracy: 0.9811
# Epoch 6/10
# 12/12 [==============================] - 6s 510ms/step - loss: 0.0247 - accuracy: 0.9919
# Epoch 7/10
# 12/12 [==============================] - 8s 642ms/step - loss: 0.0192 - accuracy: 0.9919
# Epoch 8/10
# 12/12 [==============================] - 6s 497ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 9/10
# 12/12 [==============================] - 8s 710ms/step - loss: 0.0068 - accuracy: 1.0000
# Epoch 10/10
# 12/12 [==============================] - 7s 533ms/step - loss: 0.0078 - accuracy: 1.0000
# 12/12 [==============================] - 8s 467ms/step
# 3/3 [==============================] - 2s 866ms/step
# Local Model 2 Train Accuracy: 99.73%
# Local Model 2 Train Precision: 0.99
# Local Model 2 Train Recall: 1.00
# Local Model 2 Train F1-score: 1.00
#
# Local Model 2 Test Accuracy: 95.65%
# Local Model 2 Test Precision: 0.91
# Local Model 2 Test Recall: 0.97
# Local Model 2 Test F1-score: 0.94
#
# Local Model 2 Classification Report (Train Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       248
#     Cataract       0.99      1.00      1.00       122
#
#     accuracy                           1.00       370
#    macro avg       1.00      1.00      1.00       370
# weighted avg       1.00      1.00      1.00       370
#
# Local Model 2 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#       Normal       0.98      0.95      0.97        62
#     Cataract       0.91      0.97      0.94        30
#
#     accuracy                           0.96        92
#    macro avg       0.94      0.96      0.95        92
# weighted avg       0.96      0.96      0.96        92
#
# Epoch 1/10
# 9/9 [==============================] - 13s 539ms/step - loss: 0.3689 - accuracy: 0.8815
# Epoch 2/10
# 9/9 [==============================] - 6s 611ms/step - loss: 0.2101 - accuracy: 0.9373
# Epoch 3/10
# 9/9 [==============================] - 4s 485ms/step - loss: 0.0526 - accuracy: 0.9791
# Epoch 4/10
# 9/9 [==============================] - 4s 492ms/step - loss: 0.0258 - accuracy: 0.9930
# Epoch 5/10
# 9/9 [==============================] - 6s 686ms/step - loss: 0.0128 - accuracy: 0.9965
# Epoch 6/10
# 9/9 [==============================] - 5s 502ms/step - loss: 0.0060 - accuracy: 1.0000
# Epoch 7/10
# 9/9 [==============================] - 5s 507ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 8/10
# 9/9 [==============================] - 6s 646ms/step - loss: 0.0032 - accuracy: 1.0000
# Epoch 9/10
# 9/9 [==============================] - 5s 533ms/step - loss: 0.0026 - accuracy: 1.0000
# Epoch 10/10
# 9/9 [==============================] - 5s 504ms/step - loss: 0.0021 - accuracy: 1.0000
# 9/9 [==============================] - 6s 495ms/step
# 3/3 [==============================] - 2s 500ms/step
# Local Model 3 Train Accuracy: 100.00%
# Local Model 3 Train Precision: 1.00
# Local Model 3 Train Recall: 1.00
# Local Model 3 Train F1-score: 1.00
#
# Local Model 3 Test Accuracy: 92.96%
# Local Model 3 Test Precision: 0.88
# Local Model 3 Test Recall: 0.91
# Local Model 3 Test F1-score: 0.89
#
# Local Model 3 Classification Report (Train Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       182
#     Cataract       1.00      1.00      1.00       105
#
#     accuracy                           1.00       287
#    macro avg       1.00      1.00      1.00       287
# weighted avg       1.00      1.00      1.00       287
#
# Local Model 3 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#       Normal       0.96      0.94      0.95        48
#     Cataract       0.88      0.91      0.89        23
#
#     accuracy                           0.93        71
#    macro avg       0.92      0.93      0.92        71
# weighted avg       0.93      0.93      0.93        71
#
# Epoch 1/10
# 6/6 [==============================] - 11s 516ms/step - loss: 0.8479 - accuracy: 0.8177
# Epoch 2/10
# 6/6 [==============================] - 4s 616ms/step - loss: 0.3734 - accuracy: 0.9392
# Epoch 3/10
# 6/6 [==============================] - 3s 491ms/step - loss: 0.1503 - accuracy: 0.9613
# Epoch 4/10
# 6/6 [==============================] - 3s 451ms/step - loss: 0.0594 - accuracy: 0.9890
# Epoch 5/10
# 6/6 [==============================] - 3s 458ms/step - loss: 0.1405 - accuracy: 0.9724
# Epoch 6/10
# 6/6 [==============================] - 3s 460ms/step - loss: 0.0164 - accuracy: 0.9890
# Epoch 7/10
# 6/6 [==============================] - 4s 626ms/step - loss: 0.0170 - accuracy: 0.9945
# Epoch 8/10
# 6/6 [==============================] - 3s 559ms/step - loss: 1.5076e-04 - accuracy: 1.0000
# Epoch 9/10
# 6/6 [==============================] - 3s 476ms/step - loss: 8.9726e-04 - accuracy: 1.0000
# Epoch 10/10
# 6/6 [==============================] - 3s 471ms/step - loss: 0.0028 - accuracy: 1.0000
# 6/6 [==============================] - 6s 467ms/step
# 2/2 [==============================] - 1s 234ms/step
# Local Model 4 Train Accuracy: 100.00%
# Local Model 4 Train Precision: 1.00
# Local Model 4 Train Recall: 1.00
# Local Model 4 Train F1-score: 1.00
#
# Local Model 4 Test Accuracy: 100.00%
# Local Model 4 Test Precision: 1.00
# Local Model 4 Test Recall: 1.00
# Local Model 4 Test F1-score: 1.00
#
# Local Model 4 Classification Report (Train Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       138
#     Cataract       1.00      1.00      1.00        43
#
#     accuracy                           1.00       181
#    macro avg       1.00      1.00      1.00       181
# weighted avg       1.00      1.00      1.00       181
#
# Local Model 4 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00        32
#     Cataract       1.00      1.00      1.00        13
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45
# Epoch 1/10
# 5/5 [==============================] - 12s 477ms/step - loss: 2.0537 - accuracy: 0.6216
# Epoch 2/10
# 5/5 [==============================] - 2s 452ms/step - loss: 0.5661 - accuracy: 0.8581
# Epoch 3/10
# 5/5 [==============================] - 2s 454ms/step - loss: 0.5643 - accuracy: 0.8716
# Epoch 4/10
# 5/5 [==============================] - 3s 535ms/step - loss: 0.1670 - accuracy: 0.9459
# Epoch 5/10
# 5/5 [==============================] - 3s 611ms/step - loss: 0.2175 - accuracy: 0.9324
# Epoch 6/10
# 5/5 [==============================] - 3s 484ms/step - loss: 0.0287 - accuracy: 0.9932
# Epoch 7/10
# 5/5 [==============================] - 2s 449ms/step - loss: 0.0813 - accuracy: 0.9662
# Epoch 8/10
# 5/5 [==============================] - 2s 454ms/step - loss: 0.0238 - accuracy: 0.9932
# Epoch 9/10
# 5/5 [==============================] - 2s 477ms/step - loss: 0.0257 - accuracy: 0.9932
# Epoch 10/10
# 5/5 [==============================] - 3s 523ms/step - loss: 0.0213 - accuracy: 0.9932
# 5/5 [==============================] - 5s 439ms/step
# 2/2 [==============================] - 1s 279ms/step
# Local Model 5 Train Accuracy: 100.00%
# Local Model 5 Train Precision: 1.00
# Local Model 5 Train Recall: 1.00
# Local Model 5 Train F1-score: 1.00
#
# Local Model 5 Test Accuracy: 97.22%
# Local Model 5 Test Precision: 1.00
# Local Model 5 Test Recall: 0.89
# Local Model 5 Test F1-score: 0.94
#
# Local Model 5 Classification Report (Train Data):
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00       113
#     Cataract       1.00      1.00      1.00        35
#
#     accuracy                           1.00       148
#    macro avg       1.00      1.00      1.00       148
# weighted avg       1.00      1.00      1.00       148
#
# Local Model 5 Classification Report (Test Data):
#               precision    recall  f1-score   support
#
#       Normal       0.96      1.00      0.98        27
#     Cataract       1.00      0.89      0.94         9
#
#     accuracy                           0.97        36
#    macro avg       0.98      0.94      0.96        36
# weighted avg       0.97      0.97      0.97        36
#
# 51/51 [==============================] - 31s 506ms/step - loss: 0.3796 - accuracy: 0.7967
# Global Model Accuracy: 79.67%
# 51/51 [==============================] - 32s 561ms/step
# 51/51 [==============================] - 29s 570ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.77      0.99      0.87      1074
#     Cataract       0.94      0.42      0.58       544
#
#     accuracy                           0.80      1618
#    macro avg       0.86      0.70      0.72      1618
# weighted avg       0.83      0.80      0.77      1618
#
# 51/51 [==============================] - 29s 578ms/step
# Global Model Train Accuracy: 79.67%
# Global Model Train Precision: 0.94
# Global Model Train Recall: 0.42
# Global Model Train F1-score: 0.58
#
# 51/51 [==============================] - 29s 567ms/step
# Global Model Test Accuracy: 79.67%
# Global Model Test Precision: 0.94
# Global Model Test Recall: 0.42
# Global Model Test F1-score: 0.58
